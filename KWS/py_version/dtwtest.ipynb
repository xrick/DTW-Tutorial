# %%
import librosa
import matplotlib.pyplot as plt
from matplotlib import cm
from dtw import dtw
import numpy as np
import sys
from numpy.linalg import norm
np.set_printoptions(threshold=sys.maxsize)

# %%
tmp1, sr1 = librosa.load("datasets/train_data/tmp/record01.wav")
tmp2, sr2 = librosa.load("datasets/train_data/tmp/record02.wav")
tmp3, sr3 = librosa.load("datasets/train_data/tmp/record03.wav")
tmp4, sr4 = librosa.load("datasets/train_data/tmp/record04.wav")
tmp5, sr5 = librosa.load("datasets/train_data/tmp/record05.wav")
tmp6, sr6 = librosa.load("datasets/train_data/tmp/record06.wav")
tmp7, sr7 = librosa.load("datasets/train_data/tmp/record07.wav")
tmp8, sr8 = librosa.load("datasets/train_data/tmp/record08.wav")
tmp9, sr9 = librosa.load("datasets/train_data/tmp/record09.wav")
tmp10, sr10 = librosa.load("datasets/train_data/tmp/record10.wav")
with open("datasets/train_data/tmp/record10.wav","rb") as fs:
     with open("record10.txt","wb") as tfs:
        lines = fs.readlines()
        for idx in range(len(lines)):
            print(lines[idx])
            
#         print(len(lines))
# Out:
# b'RIFF$p\x01\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x02\x00\x80>\x00\x00\x00\xfa\x00\x00\x04\x00\x10\x00data\x00p
# ...

# %%
print("the legth of tmp2 is {}".format(len(tmp2)))
# Out:
# the legth of tmp2 is 39984

# %%
mfcc1 = librosa.feature.mfcc(tmp1, sr1)
mfcc2 = librosa.feature.mfcc(tmp2, sr2)
mfcc3 = librosa.feature.mfcc(tmp3, sr3)
mfcc4 = librosa.feature.mfcc(tmp4, sr4)
mfcc5 = librosa.feature.mfcc(tmp5, sr5)
mfcc6 = librosa.feature.mfcc(tmp6, sr6)
mfcc7 = librosa.feature.mfcc(tmp7, sr7)
mfcc8 = librosa.feature.mfcc(tmp8, sr8)
mfcc9 = librosa.feature.mfcc(tmp9, sr9)
mfcc10 = librosa.feature.mfcc(tmp10, sr10)

# print("mfcc1 is {}".format(mfcc1))
# print("length of mfcc1 is {}".format(len(mfcc1)))

# %%
mfcc_data1 = np.swapaxes(mfcc1, 0 ,1)
mfcc_data2 = np.swapaxes(mfcc2, 0, 1)

fig, ax = plt.subplots()
cax = ax.imshow(mfcc_data1, interpolation='nearest', cmap=cm.coolwarm, origin='lower')
ax.set_title('MFCC')

fig1, ax1 = plt.subplots()
cax1 = ax1.imshow(mfcc_data2, interpolation='nearest', cmap=cm.coolwarm, origin='lower')
ax1.set_title('MFCC')

plt.show()

# %%
distlst = []
dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)

print('record01 - record02 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc3.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record03 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc4.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record04 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc5.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record05 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc6.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record06 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc7.T,dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record07 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc8.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record08 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc9.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record09 :', dist)
distlst.append(dist)

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc10.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record01 - record10 :', dist)
distlst.append(dist)

with open("experiment01.csv","w") as f:
    for e in range(0,9):
        f.write(str(distlst[e]))
        f.write(",")

print('========second round=========')
distlst2 = []
dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc1.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record1 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc3.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record3 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc4.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record4 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc5.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record5 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc6.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record6 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc7.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record7 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc8.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record8 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc9.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record9 :', dist)
distlst2.append(dist)

dist, cost, acc_cost, path = dtw(mfcc2.T, mfcc10.T, dist=lambda x, y: norm(x - y, ord=1), warp=7)
print('record2 - record10 :', dist)
distlst2.append(dist)

with open("experiment02.csv","w") as f:
    for e in range(0,9):
        f.write(str(distlst2[e]))
        f.write(",")
# Out:
# r is 87 and c is 79
# record01 - record02 : 422.8677444458008
# r is 87 and c is 73
# record01 - record03 : 346.1937789916992
# r is 87 and c is 66
# record01 - record04 : 459.9028778076172
# r is 87 and c is 63
# record01 - record05 : 295.9749450683594
# r is 87 and c is 57
# record01 - record06 : 364.9147415161133
# r is 87 and c is 55
# record01 - record07 : 431.3342742919922
# r is 87 and c is 77
# record01 - record08 : 390.05672454833984
# r is 87 and c is 80
# record01 - record09 : 432.40028381347656
# r is 87 and c is 64
# record01 - record10 : 424.9020690917969
# ========second round=========
# r is 79 and c is 87
# record2 - record1 : 437.80725860595703
# r is 79 and c is 73
# record2 - record3 : 435.06790924072266
# r is 79 and c is 66
# record2 - record4 : 465.14730072021484
# r is 79 and c is 63
# record2 - record5 : 412.0839614868164
# r is 79 and c is 57
# record2 - record6 : 517.2689819335938
# r is 79 and c is 55
# record2 - record7 : 464.0965118408203
# ...
